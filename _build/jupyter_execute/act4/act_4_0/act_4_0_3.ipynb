# %% [markdown]
# # 12. Grants

# %%
import pandas as pd

# Set Pandas display options: everything on one line, no truncation
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)

# Function to left-align all columns
def left_justify_all_columns(df):
    left_aligned_df = df.style.set_properties(**{'text-align': 'left'})
    left_aligned_df = left_aligned_df.set_table_styles(
        dict(selector='th', props=[('text-align', 'left')])
    )
    return left_aligned_df

# Define data
data = {
    'Grant Code': ['R01', 'R21', 'F31', 'F32', 'K08', 'T32', 'DARPA-XX', 'SBIR', 'NSF-XX'],
    'Grant Name': ['Research Project Grant', 'Exploratory/Developmental Research Grant', 'Predoctoral Individual National Research Service Award', 'Postdoctoral Individual National Research Service Award', 'Mentored Clinical Scientist Research Career Development Award', 'Institutional National Research Service Award', 'Defense Advanced Research Projects Agency', 'Small Business Innovation Research', 'National Science Foundation'],
    'Target': ['Faculty, Staff', 'Faculty, Staff', 'Graduate Students', 'Postdocs', 'Early Career Faculty', 'Undergrads, Grads, Postdocs', 'Faculty, Staff, Collaborators', 'Small Business, Faculty', 'Faculty, Staff, Collaborators'],
    'Schpiel': [
        'Supports a discrete project to improve health.',
        'Supports exploration of a new research concept.',
        'Supports promising predoctoral students.',
        'Supports promising postdoctoral students.',
        'Supports career dev. for those with clinical doctoral degree.',
        'Trainees appointed by institution.',
        'DARPA funds cutting-edge tech and science projects.',
        'Grants for small business/startup research.',
        'Funding for scientific and engineering research.'
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Left-align all columns and display table
df.style.set_table_styles({
    'Grant Code': [{'selector': '',
                    'props': [('text-align', 'left')]}],
    'Grant Name': [{'selector': '',
                    'props': [('text-align', 'left')]}],
    'Target': [{'selector': '',
                'props': [('text-align', 'left')]}],
    'Schpiel': [{'selector': '',
                 'props': [('text-align', 'left')]}]
})
# Out:
# <style type="text/css">
# #T_2679f .col0 {
#   text-align: left;
# }
# #T_2679f .col1 {
#   text-align: left;
# }
# #T_2679f .col2 {
#   text-align: left;
# }
# #T_2679f .col3 {
#   text-align: left;
# }
# </style>
# <table id="T_2679f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2679f_level0_col0" class="col_heading level0 col0" >Grant Code</th>
#       <th id="T_2679f_level0_col1" class="col_heading level0 col1" >Grant Name</th>
#       <th id="T_2679f_level0_col2" class="col_heading level0 col2" >Target</th>
#       <th id="T_2679f_level0_col3" class="col_heading level0 col3" >Schpiel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2679f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2679f_row0_col0" class="data row0 col0" >R01</td>
#       <td id="T_2679f_row0_col1" class="data row0 col1" >Research Project Grant</td>
# ...
