# %% [markdown]
# 1. [Patient survival/death](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/1.patient.survival.do): Refers to whether the patient survived following the transplantation or not.
# 2. [Graft survival](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/2.graft.survival.do): Relates to the success of the transplanted organ. Death-censored refers to the survival of the graft without considering the death of the patient as a failure, while all-cause includes all reasons.
# 3. [DGF (Delayed Graft Function)](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/3.dgf.do): A complication where the kidney doesn't function immediately after transplantation.
# 4. [PNF (Primary Non-Function)](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/4.pnf.do): When the transplanted kidney never functions.
# 5. [Acute rejection](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/5.acute.rejection.do): The body’s immediate reaction to recognizing the kidney as foreign.
# 6. [Racial category](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/6.racial.category.do): The race of the patient, which may be considered in studies examining disparities in transplant outcomes.
# 7. [PRA (Panel Reactive Antibody), Time-varying PRA](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/7.pra.do): Measures how likely a patient will react against different human leukocyte antigens (HLA).
# 8. [Kidney disease etiology/diagnosis](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/8.kidney.disease.etiology.do): The underlying cause or diagnosis of the kidney disease.
# 9. [Fix ABO](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/9.fix.abo.do)/[ABO mismatch](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/9.abo.mismatch.do): Blood type matching and compatibility between donor and recipient.
# 10. [Age](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/10.age.do) at transplant in years.
# 11. [BMI](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/11.bmi.do): Body Mass Index, a measure of body fat.
# 12. [CIT (Cold Ischemia Time)](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/12.cit.do): The time the organ is kept on ice before transplantation.
# 13. [Donor DM, HTN, terminal SCr > 1.5, ECD](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/13.donorDM.htn.scr.ecd.do), [SCr Assessment](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/13.SCr.Assessment.do): Characteristics of the donor, such as diabetes mellitus, hypertension, terminal serum creatinine, and extended criteria donor classification.
# 14. [HLA mismatch](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/14.hla.mismatch.do): Differences in human leukocyte antigens between donor and recipient.
# 15. [Duration of pre-KT dialysis](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/15.duration.of.dialysis.do): The time on dialysis before kidney transplantation.
# 16. HCV: Hepatitis C virus, considered for [candidate](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/16.candidate.hcv.do), [recipient](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/16.recipient.hcv.do), and [donor](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/16.donor.hcv.do).
# 17. [HCC](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/17.hcc.do): Hepatocellular carcinoma, a type of liver cancer.
# 18. [Immunosuppression/Induction](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/18.immunosuppression.do): Medications to prevent organ rejection.
# 19. [Insurance](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/19.insurance.do): Coverage for the transplantation procedure.
# 20. [KDRI/KDPI](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/20.kdpr.do), [DRI](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/21.dri.do), [EPTS](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/22.epts.do): Various scores and indices to evaluate the quality and suitability of a donor organ.
# 21. [Machine perfusion](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/23.machine.perfusion.do): A method to preserve organs outside the body.
# 22. [MELD](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/24.meld.do): Model for End-Stage Liver Disease score, used to prioritize liver transplant candidates.
# 23. [Previous solid organ Tx/previous KT](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/25.previous.transplant.do): History of prior organ transplants or kidney transplants.
# 24. [Organ Sharing](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/26.organ.sharing.do): Policies governing how organs are allocated.
# 25. [De-identification Code](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/27.d-identification.code.do): A code to anonymize patient information.
# 26. [Transplant Date](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/28.transplant.date.do): The date when the transplant was performed.
# 27. [LDPKI](https://raw.githubusercontent.com/jhufena/home/main/act0/act0_2/act0_2_1/29.ldpki.do): Living Donor Profile Index, a measure used to assess the quality of living kidney donors.
#
# These terms encompass a complex and multifaceted procedure, reflecting the many variables and factors that can affect the outcomes of a kidney transplant.
#
# Some additional notes on the data can be found [here](./act0_0_7_10.ipynb)
